# %% [markdown]
# # Importing the required libraries

# %%
import numpy as np
import pandas as pd
import pickle
import cv2
import sys
import keras
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.metrics import categorical_accuracy
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import image
from keras_preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %matplotlib inline
sns.set()

# %%
print(f"Python version: {sys.version}")
print(f"Tensorflow version: {tf.__version__}")
print(f"Keras version: {keras.__version__}")
print(f"OpenCV version: {cv2.__version__}")

print(f"GPU is available: {tf.test.is_gpu_available()}")
# Out:
# Python version: 3.7.12 | packaged by conda-forge | (default, Oct 26 2021, 06:08:53)
# [GCC 9.4.0]
# Tensorflow version: 2.9.2
# Keras version: 2.9.0
# OpenCV version: 4.5.4
# GPU is available: True

# %%
EPOCHS = 60
INIT_LR = 1e-3 # 1E-3
BS = 32
width=128
height=128
default_image_size = tuple((height,width))
image_size = 0
directory_root = '/kaggle/input/plantdisease'
depth=3

# %% [markdown]
# We defined a function to convert image to a Numpy array.

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
def load_image_from_dir(start=0, end=500, image_list=[], label_list=[]):
    try:
        print("Loading images ...")
        root_dir = listdir(directory_root)
        for directory in root_dir :
            # remove .DS_Store from list
            if directory == ".DS_Store" :
                root_dir.remove(directory)

        for plant_folder in root_dir :
            plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")

            for disease_folder in plant_disease_folder_list :
                # remove .DS_Store from list
                if disease_folder == ".DS_Store" :
                    plant_disease_folder_list.remove(disease_folder)

            for plant_disease_folder in plant_disease_folder_list:
                print(f"\t*Processing {plant_disease_folder} ...")
                plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}")

                for single_plant_disease_image in plant_disease_image_list :
                    if single_plant_disease_image == ".DS_Store" :
                        plant_disease_image_list.remove(single_plant_disease_image)
                for image in plant_disease_image_list[start:end]:
                    image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                    if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                        image_list.append(convert_image_to_array(image_directory))
                        label_list.append(plant_disease_folder)
        print("Image loading completed")  
    except Exception as e:
        print(f"Error : {e}")
    finally:
        return image_list, label_list

# %%
image_list, label_list = [], []
image_list, label_list = load_image_from_dir(
    start=0, 
    end=600, 
    image_list=image_list, 
    label_list=label_list
)
# Out:
# Loading images ...
# 	*Processing Pepper__bell___Bacterial_spot ...
# 	*Processing Potato___healthy ...
# 	*Processing Tomato_Leaf_Mold ...
# 	*Processing Tomato__Tomato_YellowLeaf__Curl_Virus ...
# 	*Processing Tomato_Bacterial_spot ...
# 	*Processing Tomato_Septoria_leaf_spot ...
# 	*Processing Tomato_healthy ...
# 	*Processing Tomato_Spider_mites_Two_spotted_spider_mite ...
# 	*Processing Tomato_Early_blight ...
# 	*Processing Tomato__Target_Spot ...
# 	*Processing Pepper__bell___healthy ...
# 	*Processing Potato___Late_blight ...
# 	*Processing Tomato_Late_blight ...
# 	*Processing Potato___Early_blight ...
# 	*Processing Tomato__Tomato_mosaic_virus ...
# 	*Processing PlantVillage ...
# Image loading completed

# %%
# Get size of processed image
image_size = len(image_list)
print(image_size)
# Out:
# 8325

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

print(label_binarizer.classes_)
# Out:
# ['Pepper__bell___Bacterial_spot' 'Pepper__bell___healthy'
#  'Potato___Early_blight' 'Potato___Late_blight' 'Potato___healthy'
#  'Tomato_Bacterial_spot' 'Tomato_Early_blight' 'Tomato_Late_blight'
#  'Tomato_Leaf_Mold' 'Tomato_Septoria_leaf_spot'
#  'Tomato_Spider_mites_Two_spotted_spider_mite' 'Tomato__Target_Spot'
#  'Tomato__Tomato_YellowLeaf__Curl_Virus' 'Tomato__Tomato_mosaic_virus'
#  'Tomato_healthy']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 255.0

# %%
print("Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(
    np_image_list, 
    image_labels, 
    test_size=0.2, 
    random_state=42
#     stratify=image_labels
)
# Out:
# Spliting data to train, test

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((6660, 128, 128, 3), (6660, 15), (1665, 128, 128, 3), (1665, 15))

# %%
aug = ImageDataGenerator(
    rotation_range=90,          # Randomly rotates images in range [-90, 90] degrees
    width_shift_range=0.1,
    height_shift_range=0.1, 
    shear_range=0.2, 
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode="nearest"         # fill newly created missing pixels during the image transformation
)

# %%
model = Sequential()
inputShape = (height, width, depth)
chanDim = -1
if K.image_data_format() == "channels_first":
    inputShape = (depth, height, width)
    chanDim = 1
model.add(Conv2D(32, (3, 3), padding="same",input_shape=inputShape))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Dropout(0.25))
model.add(Conv2D(64, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(Conv2D(64, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(128, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(Conv2D(128, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(1024))
model.add(Activation("relu"))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(n_classes))
model.add(Activation("softmax"))

# %%
# Get model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 32)      896
#
#  activation (Activation)     (None, 128, 128, 32)      0
#
#  batch_normalization (BatchN  (None, 128, 128, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 42, 42, 32)       0
#  )
#
#  dropout (Dropout)           (None, 42, 42, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 42, 42, 64)        18496
#
#  activation_1 (Activation)   (None, 42, 42, 64)        0
#
#  batch_normalization_1 (Batc  (None, 42, 42, 64)       256
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 42, 42, 64)        36928
#
#  activation_2 (Activation)   (None, 42, 42, 64)        0
#
#  batch_normalization_2 (Batc  (None, 42, 42, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 21, 21, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 21, 21, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 21, 21, 128)       73856
#
#  activation_3 (Activation)   (None, 21, 21, 128)       0
#
#  batch_normalization_3 (Batc  (None, 21, 21, 128)      512
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 21, 21, 128)       147584
#
#  activation_4 (Activation)   (None, 21, 21, 128)       0
#
#  batch_normalization_4 (Batc  (None, 21, 21, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 10, 10, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 10, 10, 128)       0
#
#  flatten (Flatten)           (None, 12800)             0
#
#  dense (Dense)               (None, 1024)              13108224
#
#  activation_5 (Activation)   (None, 1024)              0
#
#  batch_normalization_5 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 15)                15375
#
#  activation_6 (Activation)   (None, 15)                0
#
# =================================================================
# Total params: 13,407,119
# Trainable params: 13,404,239
# Non-trainable params: 2,880
# _________________________________________________________________

# %%
#Compiling Model
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)

model.compile(
    loss="categorical_crossentropy", 
    optimizer=opt,
    metrics=["accuracy"]
)

# %%
#Fitting Model
checkpoint_config = ModelCheckpoint('best_model.h5', 
                                    monitor='val_loss',
                                    verbose=1,
                                    save_best_only=True, 
                                    mode='auto')

history = model.fit_generator(
    aug.flow(x_train, y_train, batch_size=BS),
    validation_data=(x_test, y_test),
    steps_per_epoch=len(x_train) // BS,
    epochs=EPOCHS, 
    verbose=1,
    callbacks=[checkpoint_config]
)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/60
# 208/208 [==============================] - ETA: 0s - loss: 1.6939 - accuracy: 0.5072
# Epoch 1: val_loss improved from inf to 11.20013, saving model to best_model.h5
# 208/208 [==============================] - 33s 129ms/step - loss: 1.6939 - accuracy: 0.5072 - val_loss: 11.2001 - val_accuracy: 0.0667
# Epoch 2/60
# 208/208 [==============================] - ETA: 0s - loss: 1.1797 - accuracy: 0.6240
# Epoch 2: val_loss did not improve from 11.20013
# 208/208 [==============================] - 25s 122ms/step - loss: 1.1797 - accuracy: 0.6240 - val_loss: 12.0137 - val_accuracy: 0.0889
# Epoch 3/60
# 208/208 [==============================] - ETA: 0s - loss: 1.0456 - accuracy: 0.6737
# Epoch 3: val_loss improved from 11.20013 to 6.58710, saving model to best_model.h5
# 208/208 [==============================] - 26s 126ms/step - loss: 1.0456 - accuracy: 0.6737 - val_loss: 6.5871 - val_accuracy: 0.2973
# Epoch 4/60
# 208/208 [==============================] - ETA: 0s - loss: 0.9767 - accuracy: 0.6869
# Epoch 4: val_loss improved from 6.58710 to 3.96701, saving model to best_model.h5
# 208/208 [==============================] - 27s 128ms/step - loss: 0.9767 - accuracy: 0.6869 - val_loss: 3.9670 - val_accuracy: 0.4390
# Epoch 5/60
# 208/208 [==============================] - ETA: 0s - loss: 1.0373 - accuracy: 0.6857
# Epoch 5: val_loss did not improve from 3.96701
# 208/208 [==============================] - 26s 123ms/step - loss: 1.0373 - accuracy: 0.6857 - val_loss: 4.4799 - val_accuracy: 0.3610
# Epoch 6/60
# 208/208 [==============================] - ETA: 0s - loss: 0.8375 - accuracy: 0.7336
# Epoch 6: val_loss improved from 3.96701 to 0.92131, saving model to best_model.h5
# 208/208 [==============================] - 27s 127ms/step - loss: 0.8375 - accuracy: 0.7336 - val_loss: 0.9213 - val_accuracy: 0.7249
# Epoch 7/60
# 208/208 [==============================] - ETA: 0s - loss: 0.6740 - accuracy: 0.7769
# Epoch 7: val_loss did not improve from 0.92131
# 208/208 [==============================] - 26s 123ms/step - loss: 0.6740 - accuracy: 0.7769 - val_loss: 1.7115 - val_accuracy: 0.6402
# Epoch 8/60
# 208/208 [==============================] - ETA: 0s - loss: 0.5959 - accuracy: 0.8021
# Epoch 8: val_loss did not improve from 0.92131
# 208/208 [==============================] - 26s 123ms/step - loss: 0.5959 - accuracy: 0.8021 - val_loss: 5.2867 - val_accuracy: 0.4012
# Epoch 9/60
# 208/208 [==============================] - ETA: 0s - loss: 0.5789 - accuracy: 0.8082
# Epoch 9: val_loss did not improve from 0.92131
# 208/208 [==============================] - 26s 123ms/step - loss: 0.5789 - accuracy: 0.8082 - val_loss: 1.2989 - val_accuracy: 0.6655
# Epoch 10/60
# 208/208 [==============================] - ETA: 0s - loss: 0.6158 - accuracy: 0.8087
# Epoch 10: val_loss did not improve from 0.92131
# 208/208 [==============================] - 25s 119ms/step - loss: 0.6158 - accuracy: 0.8087 - val_loss: 13.1804 - val_accuracy: 0.1309
# Epoch 11/60
# 208/208 [==============================] - ETA: 0s - loss: 0.7714 - accuracy: 0.7544
# Epoch 11: val_loss did not improve from 0.92131
# 208/208 [==============================] - 25s 122ms/step - loss: 0.7714 - accuracy: 0.7544 - val_loss: 2.1140 - val_accuracy: 0.5634
# Epoch 12/60
# 208/208 [==============================] - ETA: 0s - loss: 0.5405 - accuracy: 0.8185
# Epoch 12: val_loss did not improve from 0.92131
# 208/208 [==============================] - 26s 123ms/step - loss: 0.5405 - accuracy: 0.8185 - val_loss: 1.0067 - val_accuracy: 0.7393
# Epoch 13/60
# 208/208 [==============================] - ETA: 0s - loss: 0.4772 - accuracy: 0.8405
# Epoch 13: val_loss did not improve from 0.92131
# 208/208 [==============================] - 26s 123ms/step - loss: 0.4772 - accuracy: 0.8405 - val_loss: 1.5519 - val_accuracy: 0.6420
# Epoch 14/60
# 208/208 [==============================] - ETA: 0s - loss: 0.4305 - accuracy: 0.8600
# Epoch 14: val_loss did not improve from 0.92131
# 208/208 [==============================] - 25s 122ms/step - loss: 0.4305 - accuracy: 0.8600 - val_loss: 1.2547 - val_accuracy: 0.7285
# Epoch 15/60
# 208/208 [==============================] - ETA: 0s - loss: 0.3851 - accuracy: 0.8678
# Epoch 15: val_loss improved from 0.92131 to 0.42654, saving model to best_model.h5
# 208/208 [==============================] - 25s 122ms/step - loss: 0.3851 - accuracy: 0.8678 - val_loss: 0.4265 - val_accuracy: 0.8703
# Epoch 16/60
# 208/208 [==============================] - ETA: 0s - loss: 0.4173 - accuracy: 0.8616
# Epoch 16: val_loss did not improve from 0.42654
# 208/208 [==============================] - 26s 123ms/step - loss: 0.4173 - accuracy: 0.8616 - val_loss: 1.9018 - val_accuracy: 0.5910
# Epoch 17/60
# 208/208 [==============================] - ETA: 0s - loss: 0.4827 - accuracy: 0.8413
# Epoch 17: val_loss did not improve from 0.42654
# 208/208 [==============================] - 25s 121ms/step - loss: 0.4827 - accuracy: 0.8413 - val_loss: 11.8842 - val_accuracy: 0.1940
# Epoch 18/60
# 208/208 [==============================] - ETA: 0s - loss: 0.3883 - accuracy: 0.8693
# Epoch 18: val_loss did not improve from 0.42654
# 208/208 [==============================] - 25s 122ms/step - loss: 0.3883 - accuracy: 0.8693 - val_loss: 0.8084 - val_accuracy: 0.7778
# Epoch 19/60
# 208/208 [==============================] - ETA: 0s - loss: 0.3370 - accuracy: 0.8837
# Epoch 19: val_loss did not improve from 0.42654
# 208/208 [==============================] - 25s 122ms/step - loss: 0.3370 - accuracy: 0.8837 - val_loss: 2.4166 - val_accuracy: 0.5646
# Epoch 20/60
# 208/208 [==============================] - ETA: 0s - loss: 0.3311 - accuracy: 0.8897
# Epoch 20: val_loss did not improve from 0.42654
# 208/208 [==============================] - 25s 122ms/step - loss: 0.3311 - accuracy: 0.8897 - val_loss: 2.5437 - val_accuracy: 0.5483
# Epoch 21/60
# 208/208 [==============================] - ETA: 0s - loss: 0.3298 - accuracy: 0.8885
# Epoch 21: val_loss did not improve from 0.42654
# 208/208 [==============================] - 25s 122ms/step - loss: 0.3298 - accuracy: 0.8885 - val_loss: 1.1783 - val_accuracy: 0.7417
# Epoch 22/60
# 208/208 [==============================] - ETA: 0s - loss: 0.3137 - accuracy: 0.8971
# Epoch 22: val_loss did not improve from 0.42654
# 208/208 [==============================] - 25s 121ms/step - loss: 0.3137 - accuracy: 0.8971 - val_loss: 0.6512 - val_accuracy: 0.7988
# Epoch 23/60
# 208/208 [==============================] - ETA: 0s - loss: 0.3247 - accuracy: 0.8951
# Epoch 23: val_loss did not improve from 0.42654
# 208/208 [==============================] - 26s 124ms/step - loss: 0.3247 - accuracy: 0.8951 - val_loss: 4.9252 - val_accuracy: 0.4492
# Epoch 24/60
# 208/208 [==============================] - ETA: 0s - loss: 0.3131 - accuracy: 0.8951
# Epoch 24: val_loss did not improve from 0.42654
# 208/208 [==============================] - 25s 122ms/step - loss: 0.3131 - accuracy: 0.8951 - val_loss: 4.7855 - val_accuracy: 0.4372
# Epoch 25/60
# 208/208 [==============================] - ETA: 0s - loss: 0.4192 - accuracy: 0.8686
# Epoch 25: val_loss did not improve from 0.42654
# 208/208 [==============================] - 25s 122ms/step - loss: 0.4192 - accuracy: 0.8686 - val_loss: 1.4844 - val_accuracy: 0.6372
# Epoch 26/60
# 208/208 [==============================] - ETA: 0s - loss: 0.3947 - accuracy: 0.8699
# Epoch 26: val_loss did not improve from 0.42654
# 208/208 [==============================] - 26s 123ms/step - loss: 0.3947 - accuracy: 0.8699 - val_loss: 5.2325 - val_accuracy: 0.4432
# Epoch 27/60
# 208/208 [==============================] - ETA: 0s - loss: 0.2853 - accuracy: 0.9040
# Epoch 27: val_loss did not improve from 0.42654
# 208/208 [==============================] - 25s 122ms/step - loss: 0.2853 - accuracy: 0.9040 - val_loss: 1.1241 - val_accuracy: 0.7946
# Epoch 28/60
# 208/208 [==============================] - ETA: 0s - loss: 0.3146 - accuracy: 0.8930
# Epoch 28: val_loss did not improve from 0.42654
# 208/208 [==============================] - 26s 126ms/step - loss: 0.3146 - accuracy: 0.8930 - val_loss: 6.8779 - val_accuracy: 0.3916
# Epoch 29/60
# 208/208 [==============================] - ETA: 0s - loss: 0.2822 - accuracy: 0.9051
# Epoch 29: val_loss did not improve from 0.42654
# 208/208 [==============================] - 27s 132ms/step - loss: 0.2822 - accuracy: 0.9051 - val_loss: 5.3309 - val_accuracy: 0.4306
# Epoch 30/60
# 208/208 [==============================] - ETA: 0s - loss: 0.2671 - accuracy: 0.9086
# Epoch 30: val_loss did not improve from 0.42654
# 208/208 [==============================] - 25s 119ms/step - loss: 0.2671 - accuracy: 0.9086 - val_loss: 4.1692 - val_accuracy: 0.4835
# Epoch 31/60
# 208/208 [==============================] - ETA: 0s - loss: 0.2448 - accuracy: 0.9167
# Epoch 31: val_loss did not improve from 0.42654
# 208/208 [==============================] - 25s 121ms/step - loss: 0.2448 - accuracy: 0.9167 - val_loss: 0.4657 - val_accuracy: 0.8637
# Epoch 32/60
# 208/208 [==============================] - ETA: 0s - loss: 0.2566 - accuracy: 0.9099
# Epoch 32: val_loss did not improve from 0.42654
# 208/208 [==============================] - 25s 121ms/step - loss: 0.2566 - accuracy: 0.9099 - val_loss: 6.9798 - val_accuracy: 0.3808
# Epoch 33/60
# 208/208 [==============================] - ETA: 0s - loss: 0.2462 - accuracy: 0.9206
# Epoch 33: val_loss did not improve from 0.42654
# 208/208 [==============================] - 25s 121ms/step - loss: 0.2462 - accuracy: 0.9206 - val_loss: 1.1713 - val_accuracy: 0.7459
# Epoch 34/60
# 208/208 [==============================] - ETA: 0s - loss: 0.2404 - accuracy: 0.9164
# Epoch 34: val_loss did not improve from 0.42654
# 208/208 [==============================] - 25s 122ms/step - loss: 0.2404 - accuracy: 0.9164 - val_loss: 2.7326 - val_accuracy: 0.6198
# Epoch 35/60
# 208/208 [==============================] - ETA: 0s - loss: 0.2332 - accuracy: 0.9244
# Epoch 35: val_loss did not improve from 0.42654
# 208/208 [==============================] - 26s 123ms/step - loss: 0.2332 - accuracy: 0.9244 - val_loss: 3.2463 - val_accuracy: 0.6216
# Epoch 36/60
# 208/208 [==============================] - ETA: 0s - loss: 0.1946 - accuracy: 0.9309
# Epoch 36: val_loss did not improve from 0.42654
# 208/208 [==============================] - 25s 122ms/step - loss: 0.1946 - accuracy: 0.9309 - val_loss: 1.0098 - val_accuracy: 0.8102
# Epoch 37/60
# 208/208 [==============================] - ETA: 0s - loss: 0.2075 - accuracy: 0.9303
# Epoch 37: val_loss improved from 0.42654 to 0.37334, saving model to best_model.h5
# 208/208 [==============================] - 26s 124ms/step - loss: 0.2075 - accuracy: 0.9303 - val_loss: 0.3733 - val_accuracy: 0.8841
# Epoch 38/60
# 208/208 [==============================] - ETA: 0s - loss: 0.5018 - accuracy: 0.8399
# Epoch 38: val_loss did not improve from 0.37334
# 208/208 [==============================] - 25s 122ms/step - loss: 0.5018 - accuracy: 0.8399 - val_loss: 8.9978 - val_accuracy: 0.2907
# Epoch 39/60
# 208/208 [==============================] - ETA: 0s - loss: 0.3179 - accuracy: 0.8959
# Epoch 39: val_loss did not improve from 0.37334
# 208/208 [==============================] - 25s 122ms/step - loss: 0.3179 - accuracy: 0.8959 - val_loss: 0.9997 - val_accuracy: 0.7958
# Epoch 40/60
# 208/208 [==============================] - ETA: 0s - loss: 0.2473 - accuracy: 0.9151
# Epoch 40: val_loss improved from 0.37334 to 0.34276, saving model to best_model.h5
# 208/208 [==============================] - 26s 123ms/step - loss: 0.2473 - accuracy: 0.9151 - val_loss: 0.3428 - val_accuracy: 0.8847
# Epoch 41/60
# 208/208 [==============================] - ETA: 0s - loss: 0.2267 - accuracy: 0.9203
# Epoch 41: val_loss did not improve from 0.34276
# 208/208 [==============================] - 25s 122ms/step - loss: 0.2267 - accuracy: 0.9203 - val_loss: 2.0461 - val_accuracy: 0.6901
# Epoch 42/60
# 208/208 [==============================] - ETA: 0s - loss: 0.2116 - accuracy: 0.9309
# Epoch 42: val_loss did not improve from 0.34276
# 208/208 [==============================] - 26s 123ms/step - loss: 0.2116 - accuracy: 0.9309 - val_loss: 2.9442 - val_accuracy: 0.6258
# Epoch 43/60
# 208/208 [==============================] - ETA: 0s - loss: 0.2060 - accuracy: 0.9329
# Epoch 43: val_loss did not improve from 0.34276
# 208/208 [==============================] - 25s 120ms/step - loss: 0.2060 - accuracy: 0.9329 - val_loss: 1.1202 - val_accuracy: 0.7357
# Epoch 44/60
# 208/208 [==============================] - ETA: 0s - loss: 0.2746 - accuracy: 0.9120
# Epoch 44: val_loss did not improve from 0.34276
# 208/208 [==============================] - 25s 122ms/step - loss: 0.2746 - accuracy: 0.9120 - val_loss: 0.9577 - val_accuracy: 0.7778
# Epoch 45/60
# 208/208 [==============================] - ETA: 0s - loss: 0.2770 - accuracy: 0.9110
# Epoch 45: val_loss did not improve from 0.34276
# 208/208 [==============================] - 26s 123ms/step - loss: 0.2770 - accuracy: 0.9110 - val_loss: 4.0069 - val_accuracy: 0.4865
# Epoch 46/60
# 208/208 [==============================] - ETA: 0s - loss: 0.2531 - accuracy: 0.9125
# Epoch 46: val_loss did not improve from 0.34276
# 208/208 [==============================] - 25s 122ms/step - loss: 0.2531 - accuracy: 0.9125 - val_loss: 0.9300 - val_accuracy: 0.7982
# Epoch 47/60
# 208/208 [==============================] - ETA: 0s - loss: 0.1938 - accuracy: 0.9345
# Epoch 47: val_loss did not improve from 0.34276
# 208/208 [==============================] - 25s 119ms/step - loss: 0.1938 - accuracy: 0.9345 - val_loss: 1.4692 - val_accuracy: 0.7171
# Epoch 48/60
# 208/208 [==============================] - ETA: 0s - loss: 0.1792 - accuracy: 0.9386
# Epoch 48: val_loss did not improve from 0.34276
# 208/208 [==============================] - 25s 122ms/step - loss: 0.1792 - accuracy: 0.9386 - val_loss: 0.4895 - val_accuracy: 0.8553
# Epoch 49/60
# 208/208 [==============================] - ETA: 0s - loss: 0.1900 - accuracy: 0.9309
# Epoch 49: val_loss did not improve from 0.34276
# 208/208 [==============================] - 25s 121ms/step - loss: 0.1900 - accuracy: 0.9309 - val_loss: 2.6041 - val_accuracy: 0.6288
# Epoch 50/60
# 208/208 [==============================] - ETA: 0s - loss: 0.1674 - accuracy: 0.9425
# Epoch 50: val_loss did not improve from 0.34276
# 208/208 [==============================] - 25s 121ms/step - loss: 0.1674 - accuracy: 0.9425 - val_loss: 2.4030 - val_accuracy: 0.6480
# Epoch 51/60
# 208/208 [==============================] - ETA: 0s - loss: 0.1499 - accuracy: 0.9482
# Epoch 51: val_loss did not improve from 0.34276
# 208/208 [==============================] - 25s 121ms/step - loss: 0.1499 - accuracy: 0.9482 - val_loss: 0.5517 - val_accuracy: 0.8625
# Epoch 52/60
# 208/208 [==============================] - ETA: 0s - loss: 0.1520 - accuracy: 0.9466
# Epoch 52: val_loss did not improve from 0.34276
# 208/208 [==============================] - 25s 118ms/step - loss: 0.1520 - accuracy: 0.9466 - val_loss: 1.9744 - val_accuracy: 0.7357
# Epoch 53/60
# 208/208 [==============================] - ETA: 0s - loss: 0.1389 - accuracy: 0.9532
# Epoch 53: val_loss did not improve from 0.34276
# 208/208 [==============================] - 25s 121ms/step - loss: 0.1389 - accuracy: 0.9532 - val_loss: 1.4919 - val_accuracy: 0.7706
# Epoch 54/60
# 208/208 [==============================] - ETA: 0s - loss: 0.1600 - accuracy: 0.9466
# Epoch 54: val_loss did not improve from 0.34276
# 208/208 [==============================] - 25s 121ms/step - loss: 0.1600 - accuracy: 0.9466 - val_loss: 5.3298 - val_accuracy: 0.5201
# Epoch 55/60
# 208/208 [==============================] - ETA: 0s - loss: 0.1795 - accuracy: 0.9419
# Epoch 55: val_loss did not improve from 0.34276
# 208/208 [==============================] - 25s 119ms/step - loss: 0.1795 - accuracy: 0.9419 - val_loss: 1.4642 - val_accuracy: 0.7195
# Epoch 56/60
# 208/208 [==============================] - ETA: 0s - loss: 0.1627 - accuracy: 0.9460
# Epoch 56: val_loss did not improve from 0.34276
# 208/208 [==============================] - 25s 121ms/step - loss: 0.1627 - accuracy: 0.9460 - val_loss: 5.2873 - val_accuracy: 0.5772
# Epoch 57/60
# 208/208 [==============================] - ETA: 0s - loss: 0.4706 - accuracy: 0.8621
# Epoch 57: val_loss did not improve from 0.34276
# 208/208 [==============================] - 25s 122ms/step - loss: 0.4706 - accuracy: 0.8621 - val_loss: 1.4560 - val_accuracy: 0.6607
# Epoch 58/60
# 208/208 [==============================] - ETA: 0s - loss: 0.2725 - accuracy: 0.9072
# Epoch 58: val_loss improved from 0.34276 to 0.29717, saving model to best_model.h5
# 208/208 [==============================] - 26s 125ms/step - loss: 0.2725 - accuracy: 0.9072 - val_loss: 0.2972 - val_accuracy: 0.9057
# Epoch 59/60
# 208/208 [==============================] - ETA: 0s - loss: 0.1974 - accuracy: 0.9314
# Epoch 59: val_loss did not improve from 0.29717
# 208/208 [==============================] - 26s 124ms/step - loss: 0.1974 - accuracy: 0.9314 - val_loss: 1.5174 - val_accuracy: 0.7279
# Epoch 60/60
# 208/208 [==============================] - ETA: 0s - loss: 0.1868 - accuracy: 0.9389
# Epoch 60: val_loss did not improve from 0.29717
# 208/208 [==============================] - 26s 123ms/step - loss: 0.1868 - accuracy: 0.9389 - val_loss: 4.9594 - val_accuracy: 0.5279

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))
axes[0].plot(history.history['loss'], label='train loss')
axes[0].plot(history.history['val_loss'], label='val loss')
axes[0].set_title('Epoch Losses')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].legend()

axes[1].plot(history.history['accuracy'], label='train accuracy')
axes[1].plot(history.history['val_accuracy'], label='val accuracy')
axes[1].set_title('Epoch Accuracies')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].legend()

plt.show()

# %% [markdown]
# # Calculate model accuracy

# %%
test_model = keras.models.load_model('best_model.h5')
scores = test_model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# 53/53 [==============================] - 1s 8ms/step - loss: 0.2972 - accuracy: 0.9057
# Test Accuracy: 90.57056903839111

# %% [markdown]
# # Predict from new data

# %%
def load_test_image_from_dir(start=0, end=500, image_list=[], label_list=[]):
    try:
        print("Loading images ...")
        root_dir = listdir(directory_root)
        for directory in root_dir :
            # remove .DS_Store from list
            if directory == ".DS_Store" :
                root_dir.remove(directory)

        for plant_folder in root_dir :
            plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")

            for disease_folder in plant_disease_folder_list :
                # remove .DS_Store from list
                if disease_folder == ".DS_Store" :
                    plant_disease_folder_list.remove(disease_folder)

            for plant_disease_folder in plant_disease_folder_list:
                print(f"\t*Processing {plant_disease_folder} ...")
                plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}")

                for single_plant_disease_image in plant_disease_image_list :
                    if single_plant_disease_image == ".DS_Store" :
                        plant_disease_image_list.remove(single_plant_disease_image)
                if start > len(plant_disease_image_list):
                    for image in plant_disease_image_list[0:100]:
                        image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                        if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                            image_list.append(image_directory)
                            label_list.append(plant_disease_folder)
                else:
                    for image in plant_disease_image_list[start:end]:
                        image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                        if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                            image_list.append(image_directory)
                            label_list.append(plant_disease_folder)
        print("Image loading completed")  
    except Exception as e:
        print(f"Error : {e}")
    finally:
        return image_list, label_list

# %%
test_image_list, test_label_list = [], []
test_image_list, test_label_list = load_test_image_from_dir(
    start=600, 
    end=700, 
    image_list=test_image_list, 
    label_list=test_label_list
)
# Out:
# Loading images ...
# 	*Processing Pepper__bell___Bacterial_spot ...
# 	*Processing Potato___healthy ...
# 	*Processing Tomato_Leaf_Mold ...
# 	*Processing Tomato__Tomato_YellowLeaf__Curl_Virus ...
# 	*Processing Tomato_Bacterial_spot ...
# 	*Processing Tomato_Septoria_leaf_spot ...
# 	*Processing Tomato_healthy ...
# 	*Processing Tomato_Spider_mites_Two_spotted_spider_mite ...
# 	*Processing Tomato_Early_blight ...
# 	*Processing Tomato__Target_Spot ...
# 	*Processing Pepper__bell___healthy ...
# 	*Processing Potato___Late_blight ...
# 	*Processing Tomato_Late_blight ...
# 	*Processing Potato___Early_blight ...
# 	*Processing Tomato__Tomato_mosaic_virus ...
# 	*Processing PlantVillage ...
# Image loading completed

# %%
CATEGORIES = label_binarizer.classes_.tolist()

def image_to_array(path):
    img = cv2.imread(path)
    new_arr = cv2.resize(img,(128, 128))
    new_arr = np.array(new_arr/255)
    new_arr = new_arr.reshape(-1, 128, 128, 3)
    return new_arr

print(CATEGORIES)
# Out:
# ['Pepper__bell___Bacterial_spot', 'Pepper__bell___healthy', 'Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy', 'Tomato_Bacterial_spot', 'Tomato_Early_blight', 'Tomato_Late_blight', 'Tomato_Leaf_Mold', 'Tomato_Septoria_leaf_spot', 'Tomato_Spider_mites_Two_spotted_spider_mite', 'Tomato__Target_Spot', 'Tomato__Tomato_YellowLeaf__Curl_Virus', 'Tomato__Tomato_mosaic_virus', 'Tomato_healthy']

# %%
id2label = {key: val for key, val in enumerate(label_binarizer.classes_.tolist())}
label2id = {val: key for key, val in id2label.items()}

# %%
actual = []
predicted = []

for i in range(len(test_image_list)):
    image = image_to_array(test_image_list[i])
    prediction = test_model.predict(image, verbose=0)

    actual.append(test_label_list[i])
    predicted.append(CATEGORIES[prediction.argmax()])

# %%
cm = confusion_matrix(actual, predicted, labels=CATEGORIES)
cm_df = pd.DataFrame(cm, index=CATEGORIES, columns=CATEGORIES)

plt.figure(figsize = (10,5))
sns.heatmap(cm_df, annot=True, annot_kws={"size": 8}, fmt="")
plt.title('Confusion Matrix')
plt.xlabel('Predicted', fontdict={'size': 14})
plt.ylabel('Actual', fontdict={'size': 14})
plt.show()

# %%
from sklearn.metrics import classification_report

report = classification_report(actual, predicted)

print(f'Classification report: \n{report}')
# Out:
# Classification report:
#                                              precision    recall  f1-score   support
#
#               Pepper__bell___Bacterial_spot       0.80      0.99      0.88       100
#                      Pepper__bell___healthy       0.96      1.00      0.98       100
#                       Potato___Early_blight       1.00      0.98      0.99       100
#                        Potato___Late_blight       0.87      0.96      0.91       100
#                            Potato___healthy       0.97      0.99      0.98       100
#                       Tomato_Bacterial_spot       0.78      0.98      0.87       100
#                         Tomato_Early_blight       0.93      0.66      0.77       100
#                          Tomato_Late_blight       0.90      0.86      0.88       100
#                            Tomato_Leaf_Mold       0.98      0.81      0.89       100
#                   Tomato_Septoria_leaf_spot       0.79      0.77      0.78       100
# Tomato_Spider_mites_Two_spotted_spider_mite       0.93      0.95      0.94       100
#                         Tomato__Target_Spot       0.95      0.84      0.89       100
#       Tomato__Tomato_YellowLeaf__Curl_Virus       0.94      0.97      0.96       100
#                 Tomato__Tomato_mosaic_virus       1.00      0.99      0.99       100
#                              Tomato_healthy       0.98      0.96      0.97       100
#
#                                    accuracy                           0.91      1500
#                                   macro avg       0.92      0.91      0.91      1500
#                                weighted avg       0.92      0.91      0.91      1500
