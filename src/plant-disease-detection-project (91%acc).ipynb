# %% [markdown]
# # Importing the required libraries

# %%
import numpy as np
import pandas as pd
import pickle
import cv2
import sys
import keras
import tensorflow as tf

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.metrics import categorical_accuracy
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import image
from keras_preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
print(f"Python version: {sys.version}")
print(f"Tensorflow version: {tf.__version__}")
print(f"Keras version: {keras.__version__}")
print(f"OpenCV version: {cv2.__version__}")
# Out:
# Python version: 3.7.12 | packaged by conda-forge | (default, Oct 26 2021, 06:08:53)
# [GCC 9.4.0]
# Tensorflow version: 2.9.2
# Keras version: 2.9.0
# OpenCV version: 4.5.4

# %%
tf.test.is_gpu_available()
# Out:
# True

# %%
EPOCHS = 50
INIT_LR = 1e-3 # 1E-3
BS = 32
width=128
height=128
default_image_size = tuple((height,width))
image_size = 0
directory_root = '/kaggle/input/plantdisease'
depth=3

# %% [markdown]
# We defined a function to convert image to a Numpy array.

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
def load_image_from_dir(start=0, end=500, image_list=[], label_list=[]):
    try:
        print("Loading images ...")
        root_dir = listdir(directory_root)
        for directory in root_dir :
            # remove .DS_Store from list
            if directory == ".DS_Store" :
                root_dir.remove(directory)

        for plant_folder in root_dir :
            plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")

            for disease_folder in plant_disease_folder_list :
                # remove .DS_Store from list
                if disease_folder == ".DS_Store" :
                    plant_disease_folder_list.remove(disease_folder)

            for plant_disease_folder in plant_disease_folder_list:
                print(f"\t*Processing {plant_disease_folder} ...")
                plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}")

                for single_plant_disease_image in plant_disease_image_list :
                    if single_plant_disease_image == ".DS_Store" :
                        plant_disease_image_list.remove(single_plant_disease_image)
                if start > len(plant_disease_image_list):
                    for image in plant_disease_image_list[0:100]:
                        image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                        if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                            image_list.append(convert_image_to_array(image_directory))
                            label_list.append(plant_disease_folder)
                else:
                    for image in plant_disease_image_list[start:end]:
                        image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                        if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                            image_list.append(convert_image_to_array(image_directory))
                            label_list.append(plant_disease_folder)
        print("Image loading completed")  
    except Exception as e:
        print(f"Error : {e}")
    finally:
        return image_list, label_list

# %%
image_list, label_list = [], []
image_list, label_list = load_image_from_dir(
    start=0, 
    end=500, 
    image_list=image_list, 
    label_list=label_list
)
# Out:
# Loading images ...
# 	*Processing Pepper__bell___Bacterial_spot ...
# 	*Processing Potato___healthy ...
# 	*Processing Tomato_Leaf_Mold ...
# 	*Processing Tomato__Tomato_YellowLeaf__Curl_Virus ...
# 	*Processing Tomato_Bacterial_spot ...
# 	*Processing Tomato_Septoria_leaf_spot ...
# 	*Processing Tomato_healthy ...
# 	*Processing Tomato_Spider_mites_Two_spotted_spider_mite ...
# 	*Processing Tomato_Early_blight ...
# 	*Processing Tomato__Target_Spot ...
# 	*Processing Pepper__bell___healthy ...
# 	*Processing Potato___Late_blight ...
# 	*Processing Tomato_Late_blight ...
# 	*Processing Potato___Early_blight ...
# 	*Processing Tomato__Tomato_mosaic_virus ...
# 	*Processing PlantVillage ...
# Image loading completed

# %%
# Get size of processed image
image_size = len(image_list)
print(image_size)
# Out:
# 7025

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

print(label_binarizer.classes_)
# Out:
# ['Pepper__bell___Bacterial_spot' 'Pepper__bell___healthy'
#  'Potato___Early_blight' 'Potato___Late_blight' 'Potato___healthy'
#  'Tomato_Bacterial_spot' 'Tomato_Early_blight' 'Tomato_Late_blight'
#  'Tomato_Leaf_Mold' 'Tomato_Septoria_leaf_spot'
#  'Tomato_Spider_mites_Two_spotted_spider_mite' 'Tomato__Target_Spot'
#  'Tomato__Tomato_YellowLeaf__Curl_Virus' 'Tomato__Tomato_mosaic_virus'
#  'Tomato_healthy']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %%
print("Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(
    np_image_list, 
    image_labels, 
    test_size=0.2, 
    random_state=42
#     stratify=image_labels
)
# Out:
# Spliting data to train, test

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((5620, 128, 128, 3), (5620, 15), (1405, 128, 128, 3), (1405, 15))

# %%
aug = ImageDataGenerator(
    rotation_range=45,          # Randomly rotates images in range [-45, 45] degrees
    width_shift_range=0.1,
    height_shift_range=0.1, 
    shear_range=0.2, 
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode="nearest"         # fill newly created missing pixels during the image transformation
)

# %%
model = Sequential()
inputShape = (height, width, depth)
chanDim = -1
if K.image_data_format() == "channels_first":
    inputShape = (depth, height, width)
    chanDim = 1
model.add(Conv2D(32, (3, 3), padding="same",input_shape=inputShape))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Dropout(0.25))
model.add(Conv2D(64, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(Conv2D(64, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(128, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(Conv2D(128, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(1024))
model.add(Activation("relu"))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(n_classes))
model.add(Activation("softmax"))

# %%
# Get model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 32)      896
#
#  activation (Activation)     (None, 128, 128, 32)      0
#
#  batch_normalization (BatchN  (None, 128, 128, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 42, 42, 32)       0
#  )
#
#  dropout (Dropout)           (None, 42, 42, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 42, 42, 64)        18496
#
#  activation_1 (Activation)   (None, 42, 42, 64)        0
#
#  batch_normalization_1 (Batc  (None, 42, 42, 64)       256
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 42, 42, 64)        36928
#
#  activation_2 (Activation)   (None, 42, 42, 64)        0
#
#  batch_normalization_2 (Batc  (None, 42, 42, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 21, 21, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 21, 21, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 21, 21, 128)       73856
#
#  activation_3 (Activation)   (None, 21, 21, 128)       0
#
#  batch_normalization_3 (Batc  (None, 21, 21, 128)      512
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 21, 21, 128)       147584
#
#  activation_4 (Activation)   (None, 21, 21, 128)       0
#
#  batch_normalization_4 (Batc  (None, 21, 21, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 10, 10, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 10, 10, 128)       0
#
#  flatten (Flatten)           (None, 12800)             0
#
#  dense (Dense)               (None, 1024)              13108224
#
#  activation_5 (Activation)   (None, 1024)              0
#
#  batch_normalization_5 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 15)                15375
#
#  activation_6 (Activation)   (None, 15)                0
#
# =================================================================
# Total params: 13,407,119
# Trainable params: 13,404,239
# Non-trainable params: 2,880
# _________________________________________________________________

# %%
#Compiling Model
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)

model.compile(
    loss="categorical_crossentropy", 
    optimizer=opt,
    metrics=["accuracy"]
)

# %%
#Fitting Model
checkpoint_config = ModelCheckpoint('best_model.h5', 
                                    monitor='val_loss',
                                    verbose=1,
                                    save_best_only=True, 
                                    mode='auto')

history = model.fit_generator(
    aug.flow(x_train, y_train, batch_size=BS),
    validation_data=(x_test, y_test),
    steps_per_epoch=len(x_train) // BS,
    epochs=EPOCHS, 
    verbose=1,
    callbacks=[checkpoint_config]
)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/50
# 175/175 [==============================] - ETA: 0s - loss: 1.7104 - accuracy: 0.5091
# Epoch 1: val_loss improved from inf to 15.59138, saving model to best_model.h5
# 175/175 [==============================] - 28s 128ms/step - loss: 1.7104 - accuracy: 0.5091 - val_loss: 15.5914 - val_accuracy: 0.0705
# Epoch 2/50
# 175/175 [==============================] - ETA: 0s - loss: 1.2174 - accuracy: 0.6253
# Epoch 2: val_loss did not improve from 15.59138
# 175/175 [==============================] - 21s 119ms/step - loss: 1.2174 - accuracy: 0.6253 - val_loss: 18.5983 - val_accuracy: 0.0968
# Epoch 3/50
# 175/175 [==============================] - ETA: 0s - loss: 0.9695 - accuracy: 0.6899
# Epoch 3: val_loss improved from 15.59138 to 7.31039, saving model to best_model.h5
# 175/175 [==============================] - 21s 119ms/step - loss: 0.9695 - accuracy: 0.6899 - val_loss: 7.3104 - val_accuracy: 0.2192
# Epoch 4/50
# 175/175 [==============================] - ETA: 0s - loss: 0.9032 - accuracy: 0.7135
# Epoch 4: val_loss improved from 7.31039 to 2.95288, saving model to best_model.h5
# 175/175 [==============================] - 22s 124ms/step - loss: 0.9032 - accuracy: 0.7135 - val_loss: 2.9529 - val_accuracy: 0.4342
# Epoch 5/50
# 175/175 [==============================] - ETA: 0s - loss: 0.7616 - accuracy: 0.7591
# Epoch 5: val_loss did not improve from 2.95288
# 175/175 [==============================] - 21s 120ms/step - loss: 0.7616 - accuracy: 0.7591 - val_loss: 13.9160 - val_accuracy: 0.1495
# Epoch 6/50
# 175/175 [==============================] - ETA: 0s - loss: 0.7696 - accuracy: 0.7591
# Epoch 6: val_loss did not improve from 2.95288
# 175/175 [==============================] - 20s 116ms/step - loss: 0.7696 - accuracy: 0.7591 - val_loss: 3.3482 - val_accuracy: 0.4434
# Epoch 7/50
# 175/175 [==============================] - ETA: 0s - loss: 0.6821 - accuracy: 0.7849
# Epoch 7: val_loss did not improve from 2.95288
# 175/175 [==============================] - 21s 123ms/step - loss: 0.6821 - accuracy: 0.7849 - val_loss: 6.8536 - val_accuracy: 0.3708
# Epoch 8/50
# 175/175 [==============================] - ETA: 0s - loss: 0.7359 - accuracy: 0.7638
# Epoch 8: val_loss did not improve from 2.95288
# 175/175 [==============================] - 21s 121ms/step - loss: 0.7359 - accuracy: 0.7638 - val_loss: 4.0837 - val_accuracy: 0.4569
# Epoch 9/50
# 175/175 [==============================] - ETA: 0s - loss: 0.5684 - accuracy: 0.8125
# Epoch 9: val_loss improved from 2.95288 to 0.66457, saving model to best_model.h5
# 175/175 [==============================] - 22s 123ms/step - loss: 0.5684 - accuracy: 0.8125 - val_loss: 0.6646 - val_accuracy: 0.7730
# Epoch 10/50
# 175/175 [==============================] - ETA: 0s - loss: 0.5007 - accuracy: 0.8352
# Epoch 10: val_loss did not improve from 0.66457
# 175/175 [==============================] - 20s 116ms/step - loss: 0.5007 - accuracy: 0.8352 - val_loss: 7.9668 - val_accuracy: 0.3046
# Epoch 11/50
# 175/175 [==============================] - ETA: 0s - loss: 0.4782 - accuracy: 0.8393
# Epoch 11: val_loss improved from 0.66457 to 0.65078, saving model to best_model.h5
# 175/175 [==============================] - 21s 122ms/step - loss: 0.4782 - accuracy: 0.8393 - val_loss: 0.6508 - val_accuracy: 0.7957
# Epoch 12/50
# 175/175 [==============================] - ETA: 0s - loss: 0.4083 - accuracy: 0.8624
# Epoch 12: val_loss did not improve from 0.65078
# 175/175 [==============================] - 21s 118ms/step - loss: 0.4083 - accuracy: 0.8624 - val_loss: 4.4306 - val_accuracy: 0.4577
# Epoch 13/50
# 175/175 [==============================] - ETA: 0s - loss: 0.4223 - accuracy: 0.8613
# Epoch 13: val_loss did not improve from 0.65078
# 175/175 [==============================] - 21s 120ms/step - loss: 0.4223 - accuracy: 0.8613 - val_loss: 1.1610 - val_accuracy: 0.7402
# Epoch 14/50
# 175/175 [==============================] - ETA: 0s - loss: 0.3923 - accuracy: 0.8722
# Epoch 14: val_loss did not improve from 0.65078
# 175/175 [==============================] - 21s 118ms/step - loss: 0.3923 - accuracy: 0.8722 - val_loss: 8.3011 - val_accuracy: 0.3046
# Epoch 15/50
# 175/175 [==============================] - ETA: 0s - loss: 0.4490 - accuracy: 0.8552
# Epoch 15: val_loss did not improve from 0.65078
# 175/175 [==============================] - 21s 119ms/step - loss: 0.4490 - accuracy: 0.8552 - val_loss: 1.6541 - val_accuracy: 0.5808
# Epoch 16/50
# 175/175 [==============================] - ETA: 0s - loss: 0.3863 - accuracy: 0.8706
# Epoch 16: val_loss did not improve from 0.65078
# 175/175 [==============================] - 21s 118ms/step - loss: 0.3863 - accuracy: 0.8706 - val_loss: 4.8012 - val_accuracy: 0.4285
# Epoch 17/50
# 175/175 [==============================] - ETA: 0s - loss: 0.3438 - accuracy: 0.8871
# Epoch 17: val_loss did not improve from 0.65078
# 175/175 [==============================] - 21s 118ms/step - loss: 0.3438 - accuracy: 0.8871 - val_loss: 7.7067 - val_accuracy: 0.3459
# Epoch 18/50
# 175/175 [==============================] - ETA: 0s - loss: 0.3553 - accuracy: 0.8774
# Epoch 18: val_loss did not improve from 0.65078
# 175/175 [==============================] - 20s 116ms/step - loss: 0.3553 - accuracy: 0.8774 - val_loss: 4.1961 - val_accuracy: 0.4071
# Epoch 19/50
# 175/175 [==============================] - ETA: 0s - loss: 0.3554 - accuracy: 0.8835
# Epoch 19: val_loss did not improve from 0.65078
# 175/175 [==============================] - 21s 118ms/step - loss: 0.3554 - accuracy: 0.8835 - val_loss: 3.6081 - val_accuracy: 0.5580
# Epoch 20/50
# 175/175 [==============================] - ETA: 0s - loss: 0.3104 - accuracy: 0.8978
# Epoch 20: val_loss did not improve from 0.65078
# 175/175 [==============================] - 20s 114ms/step - loss: 0.3104 - accuracy: 0.8978 - val_loss: 10.4856 - val_accuracy: 0.3295
# Epoch 21/50
# 175/175 [==============================] - ETA: 0s - loss: 0.2839 - accuracy: 0.9037
# Epoch 21: val_loss improved from 0.65078 to 0.45542, saving model to best_model.h5
# 175/175 [==============================] - 21s 121ms/step - loss: 0.2839 - accuracy: 0.9037 - val_loss: 0.4554 - val_accuracy: 0.8555
# Epoch 22/50
# 175/175 [==============================] - ETA: 0s - loss: 0.3068 - accuracy: 0.8991
# Epoch 22: val_loss did not improve from 0.45542
# 175/175 [==============================] - 20s 115ms/step - loss: 0.3068 - accuracy: 0.8991 - val_loss: 2.3885 - val_accuracy: 0.5915
# Epoch 23/50
# 175/175 [==============================] - ETA: 0s - loss: 0.2686 - accuracy: 0.9044
# Epoch 23: val_loss did not improve from 0.45542
# 175/175 [==============================] - 20s 116ms/step - loss: 0.2686 - accuracy: 0.9044 - val_loss: 9.4060 - val_accuracy: 0.3324
# Epoch 24/50
# 175/175 [==============================] - ETA: 0s - loss: 0.2381 - accuracy: 0.9220
# Epoch 24: val_loss did not improve from 0.45542
# 175/175 [==============================] - 20s 114ms/step - loss: 0.2381 - accuracy: 0.9220 - val_loss: 0.7561 - val_accuracy: 0.8028
# Epoch 25/50
# 175/175 [==============================] - ETA: 0s - loss: 0.2748 - accuracy: 0.9091
# Epoch 25: val_loss did not improve from 0.45542
# 175/175 [==============================] - 20s 116ms/step - loss: 0.2748 - accuracy: 0.9091 - val_loss: 1.8179 - val_accuracy: 0.7473
# Epoch 26/50
# 175/175 [==============================] - ETA: 0s - loss: 0.2413 - accuracy: 0.9164
# Epoch 26: val_loss did not improve from 0.45542
# 175/175 [==============================] - 20s 115ms/step - loss: 0.2413 - accuracy: 0.9164 - val_loss: 2.3911 - val_accuracy: 0.5665
# Epoch 27/50
# 175/175 [==============================] - ETA: 0s - loss: 0.2489 - accuracy: 0.9171
# Epoch 27: val_loss did not improve from 0.45542
# 175/175 [==============================] - 20s 114ms/step - loss: 0.2489 - accuracy: 0.9171 - val_loss: 0.5944 - val_accuracy: 0.8384
# Epoch 28/50
# 175/175 [==============================] - ETA: 0s - loss: 0.2503 - accuracy: 0.9168
# Epoch 28: val_loss did not improve from 0.45542
# 175/175 [==============================] - 21s 118ms/step - loss: 0.2503 - accuracy: 0.9168 - val_loss: 6.4144 - val_accuracy: 0.3552
# Epoch 29/50
# 175/175 [==============================] - ETA: 0s - loss: 0.2436 - accuracy: 0.9186
# Epoch 29: val_loss did not improve from 0.45542
# 175/175 [==============================] - 20s 114ms/step - loss: 0.2436 - accuracy: 0.9186 - val_loss: 3.7112 - val_accuracy: 0.5210
# Epoch 30/50
# 175/175 [==============================] - ETA: 0s - loss: 0.2588 - accuracy: 0.9145
# Epoch 30: val_loss did not improve from 0.45542
# 175/175 [==============================] - 20s 116ms/step - loss: 0.2588 - accuracy: 0.9145 - val_loss: 3.6675 - val_accuracy: 0.5680
# Epoch 31/50
# 175/175 [==============================] - ETA: 0s - loss: 0.2495 - accuracy: 0.9218
# Epoch 31: val_loss did not improve from 0.45542
# 175/175 [==============================] - 21s 118ms/step - loss: 0.2495 - accuracy: 0.9218 - val_loss: 1.0349 - val_accuracy: 0.7352
# Epoch 32/50
# 175/175 [==============================] - ETA: 0s - loss: 0.2173 - accuracy: 0.9282
# Epoch 32: val_loss did not improve from 0.45542
# 175/175 [==============================] - 20s 115ms/step - loss: 0.2173 - accuracy: 0.9282 - val_loss: 4.3861 - val_accuracy: 0.4904
# Epoch 33/50
# 175/175 [==============================] - ETA: 0s - loss: 0.2059 - accuracy: 0.9311
# Epoch 33: val_loss improved from 0.45542 to 0.35596, saving model to best_model.h5
# 175/175 [==============================] - 21s 119ms/step - loss: 0.2059 - accuracy: 0.9311 - val_loss: 0.3560 - val_accuracy: 0.8911
# Epoch 34/50
# 175/175 [==============================] - ETA: 0s - loss: 0.1941 - accuracy: 0.9345
# Epoch 34: val_loss did not improve from 0.35596
# 175/175 [==============================] - 20s 116ms/step - loss: 0.1941 - accuracy: 0.9345 - val_loss: 0.5390 - val_accuracy: 0.8420
# Epoch 35/50
# 175/175 [==============================] - ETA: 0s - loss: 0.1921 - accuracy: 0.9338
# Epoch 35: val_loss did not improve from 0.35596
# 175/175 [==============================] - 21s 117ms/step - loss: 0.1921 - accuracy: 0.9338 - val_loss: 1.7370 - val_accuracy: 0.7246
# Epoch 36/50
# 175/175 [==============================] - ETA: 0s - loss: 0.2107 - accuracy: 0.9286
# Epoch 36: val_loss did not improve from 0.35596
# 175/175 [==============================] - 20s 114ms/step - loss: 0.2107 - accuracy: 0.9286 - val_loss: 1.3317 - val_accuracy: 0.7651
# Epoch 37/50
# 175/175 [==============================] - ETA: 0s - loss: 0.1926 - accuracy: 0.9352
# Epoch 37: val_loss did not improve from 0.35596
# 175/175 [==============================] - 20s 117ms/step - loss: 0.1926 - accuracy: 0.9352 - val_loss: 2.6658 - val_accuracy: 0.6477
# Epoch 38/50
# 175/175 [==============================] - ETA: 0s - loss: 0.1663 - accuracy: 0.9443
# Epoch 38: val_loss did not improve from 0.35596
# 175/175 [==============================] - 21s 117ms/step - loss: 0.1663 - accuracy: 0.9443 - val_loss: 0.4577 - val_accuracy: 0.8804
# Epoch 39/50
# 175/175 [==============================] - ETA: 0s - loss: 0.1732 - accuracy: 0.9418
# Epoch 39: val_loss did not improve from 0.35596
# 175/175 [==============================] - 21s 119ms/step - loss: 0.1732 - accuracy: 0.9418 - val_loss: 2.3122 - val_accuracy: 0.5872
# Epoch 40/50
# 175/175 [==============================] - ETA: 0s - loss: 0.1650 - accuracy: 0.9438
# Epoch 40: val_loss did not improve from 0.35596
# 175/175 [==============================] - 20s 116ms/step - loss: 0.1650 - accuracy: 0.9438 - val_loss: 2.5914 - val_accuracy: 0.5253
# Epoch 41/50
# 175/175 [==============================] - ETA: 0s - loss: 0.1914 - accuracy: 0.9361
# Epoch 41: val_loss did not improve from 0.35596
# 175/175 [==============================] - 20s 115ms/step - loss: 0.1914 - accuracy: 0.9361 - val_loss: 1.3433 - val_accuracy: 0.7345
# Epoch 42/50
# 175/175 [==============================] - ETA: 0s - loss: 0.1650 - accuracy: 0.9438
# Epoch 42: val_loss did not improve from 0.35596
# 175/175 [==============================] - 21s 118ms/step - loss: 0.1650 - accuracy: 0.9438 - val_loss: 5.9689 - val_accuracy: 0.4228
# Epoch 43/50
# 175/175 [==============================] - ETA: 0s - loss: 0.1736 - accuracy: 0.9404
# Epoch 43: val_loss did not improve from 0.35596
# 175/175 [==============================] - 20s 113ms/step - loss: 0.1736 - accuracy: 0.9404 - val_loss: 2.1582 - val_accuracy: 0.7231
# Epoch 44/50
# 175/175 [==============================] - ETA: 0s - loss: 0.1546 - accuracy: 0.9476
# Epoch 44: val_loss did not improve from 0.35596
# 175/175 [==============================] - 21s 118ms/step - loss: 0.1546 - accuracy: 0.9476 - val_loss: 1.6673 - val_accuracy: 0.7658
# Epoch 45/50
# 175/175 [==============================] - ETA: 0s - loss: 0.1532 - accuracy: 0.9483
# Epoch 45: val_loss did not improve from 0.35596
# 175/175 [==============================] - 20s 115ms/step - loss: 0.1532 - accuracy: 0.9483 - val_loss: 5.6777 - val_accuracy: 0.5367
# Epoch 46/50
# 175/175 [==============================] - ETA: 0s - loss: 0.1773 - accuracy: 0.9440
# Epoch 46: val_loss did not improve from 0.35596
# 175/175 [==============================] - 21s 117ms/step - loss: 0.1773 - accuracy: 0.9440 - val_loss: 2.1815 - val_accuracy: 0.6463
# Epoch 47/50
# 175/175 [==============================] - ETA: 0s - loss: 0.1462 - accuracy: 0.9503
# Epoch 47: val_loss did not improve from 0.35596
# 175/175 [==============================] - 20s 115ms/step - loss: 0.1462 - accuracy: 0.9503 - val_loss: 0.5865 - val_accuracy: 0.8470
# Epoch 48/50
# 175/175 [==============================] - ETA: 0s - loss: 0.2167 - accuracy: 0.9343
# Epoch 48: val_loss did not improve from 0.35596
# 175/175 [==============================] - 20s 116ms/step - loss: 0.2167 - accuracy: 0.9343 - val_loss: 1.8776 - val_accuracy: 0.7132
# Epoch 49/50
# 175/175 [==============================] - ETA: 0s - loss: 0.1461 - accuracy: 0.9513
# Epoch 49: val_loss did not improve from 0.35596
# 175/175 [==============================] - 20s 117ms/step - loss: 0.1461 - accuracy: 0.9513 - val_loss: 1.6230 - val_accuracy: 0.7438
# Epoch 50/50
# 175/175 [==============================] - ETA: 0s - loss: 0.1338 - accuracy: 0.9540
# Epoch 50: val_loss did not improve from 0.35596
# 175/175 [==============================] - 20s 115ms/step - loss: 0.1338 - accuracy: 0.9540 - val_loss: 0.3867 - val_accuracy: 0.9167

# %% [markdown]
# # Calculate model accuracy

# %%
test_model = keras.models.load_model('best_model.h5')
scores = test_model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# 44/44 [==============================] - 1s 8ms/step - loss: 0.3560 - accuracy: 0.8911
# Test Accuracy: 89.1103208065033

# %% [markdown]
# # Predict from new data

# %%
def load_test_image_from_dir(start=0, end=500, image_list=[], label_list=[]):
    try:
        print("Loading images ...")
        root_dir = listdir(directory_root)
        for directory in root_dir :
            # remove .DS_Store from list
            if directory == ".DS_Store" :
                root_dir.remove(directory)

        for plant_folder in root_dir :
            plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")

            for disease_folder in plant_disease_folder_list :
                # remove .DS_Store from list
                if disease_folder == ".DS_Store" :
                    plant_disease_folder_list.remove(disease_folder)

            for plant_disease_folder in plant_disease_folder_list:
                print(f"\t*Processing {plant_disease_folder} ...")
                plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}")

                for single_plant_disease_image in plant_disease_image_list :
                    if single_plant_disease_image == ".DS_Store" :
                        plant_disease_image_list.remove(single_plant_disease_image)
                if start > len(plant_disease_image_list):
                    for image in plant_disease_image_list[0:100]:
                        image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                        if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                            image_list.append(image_directory)
                            label_list.append(plant_disease_folder)
                else:
                    for image in plant_disease_image_list[start:end]:
                        image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                        if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                            image_list.append(image_directory)
                            label_list.append(plant_disease_folder)
        print("Image loading completed")  
    except Exception as e:
        print(f"Error : {e}")
    finally:
        return image_list, label_list

# %%
test_image_list, test_label_list = [], []
test_image_list, test_label_list = load_test_image_from_dir(
    start=500, 
    end=600, 
    image_list=test_image_list, 
    label_list=test_label_list
)
# Out:
# Loading images ...
# 	*Processing Pepper__bell___Bacterial_spot ...
# 	*Processing Potato___healthy ...
# 	*Processing Tomato_Leaf_Mold ...
# 	*Processing Tomato__Tomato_YellowLeaf__Curl_Virus ...
# 	*Processing Tomato_Bacterial_spot ...
# 	*Processing Tomato_Septoria_leaf_spot ...
# 	*Processing Tomato_healthy ...
# 	*Processing Tomato_Spider_mites_Two_spotted_spider_mite ...
# 	*Processing Tomato_Early_blight ...
# 	*Processing Tomato__Target_Spot ...
# 	*Processing Pepper__bell___healthy ...
# 	*Processing Potato___Late_blight ...
# 	*Processing Tomato_Late_blight ...
# 	*Processing Potato___Early_blight ...
# 	*Processing Tomato__Tomato_mosaic_virus ...
# 	*Processing PlantVillage ...
# Image loading completed

# %%
CATEGORIES = ['Pepper__bell___Bacterial_spot', 'Pepper__bell___healthy',
 'Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy',
 'Tomato_Bacterial_spot', 'Tomato_Early_blight', 'Tomato_Late_blight',
 'Tomato_Leaf_Mold', 'Tomato_Septoria_leaf_spot',
 'Tomato_Spider_mites_Two_spotted_spider_mite', 'Tomato__Target_Spot',
 'Tomato__Tomato_YellowLeaf__Curl_Virus', 'Tomato__Tomato_mosaic_virus',
 'Tomato_healthy']

def image_to_array(path):
    img = cv2.imread(path)
    new_arr = cv2.resize(img,(128, 128))
    new_arr = np.array(new_arr/255)
    new_arr = new_arr.reshape(-1, 128, 128, 3)
    return new_arr

# %%
actual = {_key: 0 for _key in test_label_list}
predicted = {_key: 0 for _key in test_label_list}

for i in range(len(test_image_list)):
    image = image_to_array(test_image_list[i])
    prediction = test_model.predict(image, verbose=0)
    
    actual[test_label_list[i]] += 1
    predicted[CATEGORIES[prediction.argmax()]] += 1
#     print(f"Act: {test_label_list[i]}, pred: {CATEGORIES[prediction.argmax()]}")


    
print(actual)
print(predicted)
# Out:
# {'Pepper__bell___Bacterial_spot': 100, 'Potato___healthy': 100, 'Tomato_Leaf_Mold': 100, 'Tomato__Tomato_YellowLeaf__Curl_Virus': 100, 'Tomato_Bacterial_spot': 100, 'Tomato_Septoria_leaf_spot': 100, 'Tomato_healthy': 100, 'Tomato_Spider_mites_Two_spotted_spider_mite': 100, 'Tomato_Early_blight': 100, 'Tomato__Target_Spot': 100, 'Pepper__bell___healthy': 100, 'Potato___Late_blight': 100, 'Tomato_Late_blight': 100, 'Potato___Early_blight': 100, 'Tomato__Tomato_mosaic_virus': 100}
# {'Pepper__bell___Bacterial_spot': 96, 'Potato___healthy': 101, 'Tomato_Leaf_Mold': 89, 'Tomato__Tomato_YellowLeaf__Curl_Virus': 101, 'Tomato_Bacterial_spot': 106, 'Tomato_Septoria_leaf_spot': 103, 'Tomato_healthy': 115, 'Tomato_Spider_mites_Two_spotted_spider_mite': 92, 'Tomato_Early_blight': 107, 'Tomato__Target_Spot': 107, 'Pepper__bell___healthy': 93, 'Potato___Late_blight': 104, 'Tomato_Late_blight': 72, 'Potato___Early_blight': 109, 'Tomato__Tomato_mosaic_virus': 105}

# %%
actual_labels = []
predicted_labels = []

for label, count in actual.items():
    actual_labels.extend([label] * count)
for label, count in predicted.items():
    predicted_labels.extend([label] * count)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(actual_labels, predicted_labels, labels=CATEGORIES)
cm_df = pd.DataFrame(cm, index=CATEGORIES, columns=CATEGORIES)

plt.figure(figsize = (10,5))
sns.heatmap(cm_df, annot=True, annot_kws={"size": 8}, fmt="")
plt.show()

# %%
from sklearn.metrics import classification_report

report = classification_report(actual_labels, predicted_labels)

print(f'Classification report: \n{report}')
# Out:
# Classification report:
#                                              precision    recall  f1-score   support
#
#               Pepper__bell___Bacterial_spot       1.00      0.96      0.98       100
#                      Pepper__bell___healthy       0.89      0.83      0.86       100
#                       Potato___Early_blight       0.87      0.95      0.91       100
#                        Potato___Late_blight       0.87      0.90      0.88       100
#                            Potato___healthy       0.96      0.97      0.97       100
#                       Tomato_Bacterial_spot       0.88      0.93      0.90       100
#                         Tomato_Early_blight       0.91      0.97      0.94       100
#                          Tomato_Late_blight       1.00      0.72      0.84       100
#                            Tomato_Leaf_Mold       0.97      0.86      0.91       100
#                   Tomato_Septoria_leaf_spot       0.93      0.96      0.95       100
# Tomato_Spider_mites_Two_spotted_spider_mite       0.97      0.89      0.93       100
#                         Tomato__Target_Spot       0.84      0.90      0.87       100
#       Tomato__Tomato_YellowLeaf__Curl_Virus       0.86      0.87      0.87       100
#                 Tomato__Tomato_mosaic_virus       0.95      1.00      0.98       100
#                              Tomato_healthy       0.87      1.00      0.93       100
#
#                                    accuracy                           0.91      1500
#                                   macro avg       0.92      0.91      0.91      1500
#                                weighted avg       0.92      0.91      0.91      1500
